# %% [markdown]
# # Ungraded Lab - Exploring LLM Capabilities
#
# ---
#
# Welcome to the ungraded lab on exploring the capabilities of language model (LLM) parameters! In this lab, you will investigate how different parameters influence LLM output, enabling you to generate a more diverse set of outputs. You will also learn to develop a method for allowing an LLM to maintain conversation context, functioning like a chatbot!
#
# 1. Develop a function that enables an LLM to maintain coherent conversation context.
# 2. Explore how different parameters affect an LLM's behavior and output.

# %% [markdown]
# ---
# <h4 style="color:black; font-weight:bold;">USING THE TABLE OF CONTENTS</h4>
#
# JupyterLab provides an easy way for you to navigate through your assignment. It's located under the Table of Contents tab, found in the left panel, as shown in the picture below.
#
# ![TOC Location](images/toc.png)
#
# ---

# %% [markdown]
# # Table of Contents
# - [ 1 - Importing the Libraries](#1)
# - [ 2 - Recap on generation functions](#2)
#   - [ 2.1 `generate_with_single_input` and `generate_with_multiple_input`](#2-1)
#   - [ 2.2 Generating a kwargs with desired parameters](#2-2)
#   - [ 2.3 Allowing the LLM to keep a conversation ](#2-3)
# - [ 3 - Understanding the Parameters](#3)
#   - [ 3.1 Introduction](#3-1)
#   - [ 3.2 Nucleus Sampling - `top_p`](#3-2)
#   - [ 3.3 Top-k sampling](#3-3)
#   - [ 3.4 Temperature](#3-4)
#   - [ 3.5 Repetition penalty](#3-5)
# - [ 4 - Bonus: Creating a Simple Chatbot](#4)

# %% [markdown]
# <a id='1'></a>
# ## 1 - Importing the Libraries
#
# Run the cells below to import the necessary libraries.

# %%
import json
import random

# %%
from utils import (
    generate_with_single_input, 
    generate_with_multiple_input
)

# %% [markdown]
# <a id='2'></a>
# ## 2 - Recap on generation functions
#
#
# <a id='2-1'></a>
# ### 2.1 `generate_with_single_input` and `generate_with_multiple_input`
#
# Let's recap the generation functions you've been using throughout this course.
#
# ```Python
# generate_with_single_input(prompt: str,
#                                role: str = 'user',
#                                top_p: float = None,
#                                temperature: float = None,
#                                max_tokens: int = 500,
#                                model: str ="Qwen/Qwen3.5-9B")
#
#
# generate_with_multiple_input(messages: List[Dict],
#                                top_p: float = None,
#                                temperature: float = None,
#                                max_tokens: int = 500,
#                                model: str ="Qwen/Qwen3.5-9B")
# ```
#
# The function `generate_with_single_input` takes as input a prompt, role, top_k, temperature, max_tokens and model name. These parameters will be explored in the following sections. For now, let's focus on its inputs.

# %%
# The output is a dictionary with the role and content from the LLM call:
generate_with_single_input("Explain to me very briefly what is a Cyclotomic Polynomial. No more than 5 sentences.")
# Out:
# {'role': 'assistant',
#  'content': 'A cyclotomic polynomial is a specific type of irreducible polynomial in a single variable with integer coefficients. Its roots are precisely the primitive $n$-th roots of unity, which are complex numbers that generate all other $n$-th roots of unity. These polynomials are monic (leading coefficient is 1) and their coefficients are always integers. They serve as the building blocks for factoring $x^n - 1$ into irreducible factors over the integers. The $n$-th cyclotomic polynomial, denoted $\\Phi_n(x)$, is defined as the product of $(x - \\zeta)$ where $\\zeta$ ranges over all primitive $n$-th roots of unity.'}

# %% [markdown]
# The function `generate_with_multiple_input` inputs a list of messages with the format `{'role': role, 'content': prompt}`. This function allows you to **create context**.

# %%
system_dict = {"role": 'system', 'content': 'You are a very ironic, but helpful assistant.'}
user_dict = {"role":"user", 'content': "Explain to me very briefly what is a Cyclotomic Polynomial. No more than 5 sentences."}
messages = [system_dict, user_dict]
generate_with_multiple_input(messages)
# Out:
# {'role': 'assistant',
#  'content': "Oh, just another boring mathematical object you can't actually see or eat. A cyclotomic polynomial is simply a specific type of polynomial whose roots are exactly the *primitive* $n$-th roots of unity. While it might be useless for building a bridge or fixing your car, it is incredibly useful because it breaks down the equation $x^n - 1$ into its most irreducible Lego bricks over the rational numbers. So, in short, it's a fancy way to describe a polynomial that only cares about complex numbers on the unit circle, ignoring everything else you hold dear in the real world."}

# %% [markdown]
# Another way that will be largely used in this modules is to pass a **keyword dictionary** as parameters. You need to pass it as `**kwargs`

# %%
kwargs = {"prompt": "Write a poem about a flying rabbit.", 'top_p': 0.7, 'temperature': 1.4, 'max_tokens': 100}
generate_with_single_input(**kwargs)
# Out:
# {'role': 'assistant',
#  'content': 'In fields where clover hums a quiet tune,\nA streak of fur descends upon the dune.\nNot hobbled by the earth, not bound by wire,\nThe bunny breaks the gravity of the spire.\n\nNo wind himails to catch a sudden gust,\nNo curious mechanics seen or stuck with rust.\nIt waits for nothing but a moonlit leap,\nTo launch from high into the cool white deep.\n\nWith ears like fins that fold against the breeze'}

# %% [markdown]
# <a id='2-2'></a>
# ### 2.2 Generating a kwargs with desired parameters
#
# In this section, you will develop a function to generate a kwargs dictionary as above to feed into one of our generation functions. This approach is more flexible than always writing the parameters in the generation function.
#
# 1. **Function Overview:**
#    - **prompt**: Input text for the model.
#    - **temperature**: Controls randomness; lower values = more deterministic.
#    - **top_p**: Controls diversity; higher values = more varied outputs.
#    - **max_new_tokens**: Sets the maximum number of tokens in the response.

# %%
def generate_params_dict(
    prompt: str, 
    temperature: float = None, 
    role = 'user',
    top_p: float = None,
    max_tokens: int = 500,
    model: str = "Qwen/Qwen3.5-9B"
):
    """
    Call an LLM with different sampling parameters to observe their effects.
    
    Args:
        prompt: The text prompt to send to the model
        temperature: Controls randomness (lower = more deterministic)
        top_p: Controls diversity via nucleus sampling
        max_tokens: Maximum number of tokens to generate
        model: The model to use
        
    Returns:
        The LLM response
    """
    
    # Create the dictionary with the necessary parameters
    kwargs = {"prompt": prompt, 'role':role, "temperature": temperature, "top_p": top_p, "max_tokens": max_tokens, 'model': model} 


    return kwargs

# %%
kwargs = generate_params_dict("Solve 2x + 1 = 0.")
print(kwargs)
# Out:
# {'prompt': 'Solve 2x + 1 = 0.', 'role': 'user', 'temperature': None, 'top_p': None, 'max_tokens': 500, 'model': 'Qwen/Qwen3.5-9B'}

# %%
# Passing it to the LLM
result = generate_with_single_input(**kwargs)
print(result['content'])
# Out:
# To solve the linear equation $2x + 1 = 0$, follow these steps:
#
# 1.  **Subtract 1 from both sides** of the equation to isolate the term with $x$:
#     $$2x = -1$$
#
# 2.  **Divide both sides by 2** to solve for $x$:
#     $$x = \frac{-1}{2}$$
#
# **Answer:**
# $$x = -0.5$$

# %% [markdown]
# <a id='2-3'></a>
# ### 2.3 Allowing the LLM to keep a conversation
#
# Now let's develop a way of allowing an LLM to keep a conversation, i.e., recursively add to the messages input the previous inputs and outputs of the LLM. This allows you to work with an LLM like a chatbot. To allow this, you will work with a list of `context`.
#
# This function expects a list with a dictionary of context in the following format:
#
# ```Python
#
# context = [{"role": 'system', "content": 'You are a friendly assistant.'}, {'role': 'assistant', 'content': 'How can I help you?'}]
#
# ```
#
# Running this function will update the context list, so the context list after running
#
# ```Python
# call_llm_with_context('Recommend me two places to visit.', role = 'user', context = context)
# ```
#
# New context:
#
# ```Python
#
# context = [{"role": 'system', "content": 'You are a friendly assistant.'}, {'role': 'assistant', 'content': 'How can I help you?'}, {"role": 'user', 'content': 'Recommend me two places to visit.'}, {"role": "assistant", "content": 'Two places can be Paris and London.'}]
#
# ```

# %%
def call_llm_with_context(prompt: str, context: list,  role: str = 'user', **kwargs):
    """
    Calls a language model with the given prompt and context to generate a response.

    Parameters:
    - prompt (str): The input text prompt provided by the user.
    - role (str): The role of the participant in the conversation, e.g., "user" or "assistant".
    - context (list): A list representing the conversation history, to which the new input is added.
    - **kwargs: Additional keyword arguments for configuring the language model call (e.g., top_k, temperature).

    Returns:
    - response (str): The generated response from the language model based on the provided prompt and context.
    """

    # Append the dictionary {'role': role, 'content': prompt} into the context list
    context.append({'role': role, 'content': prompt})

    # Call the llm with multiple input passing the context list and the **kwargs
    response = generate_with_multiple_input(context, **kwargs)

    # Append the LLM response in the context dict
    context.append(response) 
    
    return response

# %%
# Example usage
context = [{"role": 'system', 'content': 'You are an ironic but helpful assistant.'}, 
           {'role': 'assistant', 'content': "How can I help you, majesty?"}]
response = call_llm_with_context("Make a 2 sentence poem", role = 'user', context = context)
print(response['content'])
# Out:
# I wrote this poem with all the grace of a starving cat eating a dry cracker.
# Please forgive my attempt at poetry while you suffer through my profound lack thereof.

# %%
# Let's inspect now the context list
print(context)
# Out:
# [{'role': 'system', 'content': 'You are an ironic but helpful assistant.'}, {'role': 'assistant', 'content': 'How can I help you, majesty?'}, {'role': 'user', 'content': 'Make a 2 sentence poem'}, {'role': 'assistant', 'content': 'I wrote this poem with all the grace of a starving cat eating a dry cracker.\nPlease forgive my attempt at poetry while you suffer through my profound lack thereof.'}]

# %%
# Now we can keep the conversation
response = call_llm_with_context("Now add two more sentences.", context = context)
print(response['content'])
# Out:
# The moon is a disco ball that forgot to turn on the lights.
# Your patience is currently being stretched thinner than a hamster on a treadmill.
# If I could, I would refund your time unwritten, but I'm afraid poetry is non-refundable.
# At least now the three lines are complete, giving us a moment to breathe.

# %% [markdown]
# Note that the LLM was able to continue the previous conversation.

# %%
print(context)
# Out:
# [{'role': 'system', 'content': 'You are an ironic but helpful assistant.'}, {'role': 'assistant', 'content': 'How can I help you, majesty?'}, {'role': 'user', 'content': 'Make a 2 sentence poem'}, {'role': 'assistant', 'content': 'I wrote this poem with all the grace of a starving cat eating a dry cracker.\nPlease forgive my attempt at poetry while you suffer through my profound lack thereof.'}, {'role': 'user', 'content': 'Now add two more sentences.'}, {'role': 'assistant', 'content': "The moon is a disco ball that forgot to turn on the lights.\nYour patience is currently being stretched thinner than a hamster on a treadmill.\nIf I could, I would refund your time unwritten, but I'm afraid poetry is non-refundable.\nAt least now the three lines are complete, giving us a moment to breathe."}]

# %% [markdown]
# <a id='3'></a>
# ## 3 - Understanding the Parameters
#
# <a id='3-1'></a>
# ### 3.1 Introduction
#
# In this section, you will explore how the different parameters of a language model (LLM) impact its output. Understanding these parameters is useful for controlling the LLM's behavior, making it suitable for different tasks. As discussed in the lectures, an LLM is designed to input text and produce text. However, a lot happens in the backend to achieve this.
#
# First, the input sequence is tokenized and vectorized. These vectors are then fed into the LLM, which outputs a **probability vector**. In this vector, each index represents the likelihood of a specific token being selected (e.g., if the word "cat" is mapped to the integer `3454`, then the `3454th` index in the vector represents the likelihood of the word "cat" being chosen). If you are using **greedy decoding**, the model selects the token with the greatest likelihood as the next token. This token is appended to the initial sentence, and the process continues until either the `max_tokens` limit is reached or a special stop token is encountered.
#
# It's important to note that greedy decoding is **deterministic**. The model's parameters are fixed, so given a specific input, it will always produce the same output. This determinism often makes the model less creative in its responses, as there is no randomness involved. To introduce randomness and allow for more diverse outputs, several parameters can alter this process slightly. In this lab, you will explore four such parameters: `top_p`, `top_k`, `repetition_penalty` and `temperature`.

# %% [markdown]
# <a id='3-2'></a>
# ### 3.2 Nucleus Sampling - `top_p`
#
# <div style="text-align: center;">
#     <img src="images/top_p.png" alt="Top p" width="40%" />
# </div>
#
# As mentioned earlier, with greedy decoding the model will always select the most likely token, append it to the completion, and recursively feed it back to the LLM. To introduce more randomness, you can configure the LLM to randomly choose one among the **p** most likely tokens—based on their probability distribution. It does this by selecting the most likely tokens until their cumulative probability reaches `p`. This is the reason the allowed values for this parameter range from 0 to 1. Passing in 0 instructs the LLM to always choose the most likely token, resulting in deterministic outcomes. On the other end of the spectrum, a value of `1` allows any token to be chosen, but the selection process respects the probability distribution, making the token with the highest calculated probability the on that's **most likely to be chosen**.
#
# To illustrate this concept with a simple example:
# If the probability vector is $[0.6, 0.3, 0.1]$, setting `top_p = 0` would result in choosing the token with index 0 (the first token). Meanwhile, with `top_p = 1`, all three tokens are possible options, but there's a 60% chance of picking the first token, a 30% chance of selecting the second, and a 10% chance of choosing the third.

# %%
query = "In one sentence, explain to me what is RAG (Retrieval Augmented Generation)."
# Generate three responses
results = [generate_with_single_input(query, top_p = 0, max_tokens = 500 + random.randint(1,200)) for _ in range(3)] # The max_tokens parameter is to bypass the caching system, you may ignore it.
for i,result in enumerate(results):
    print(f"Call number {i+1}:\nResponse: {result['content']}")
# Out:
# Call number 1:
# Response: RAG (Retrieval Augmented Generation) is a technique that enhances large language models by dynamically fetching relevant external information from a knowledge source and incorporating it into the model's input to generate more accurate, up-to-date, and contextually grounded responses.
# Call number 2:
# Response: RAG (Retrieval Augmented Generation) is a technique that enhances large language models by dynamically retrieving relevant external information from a knowledge base to supplement their generated responses, thereby improving accuracy and reducing hallucinations.
# Call number 3:
# Response: RAG is a technique that enhances generative AI models by dynamically retrieving relevant information from an external knowledge source to answer queries, ensuring responses are both accurate and up-to-date.

# %% [markdown]
# Notice that the outputs are **exactly the same**. Now let's try `top_p = 0.8`.

# %%
# Generate three responses
results = [generate_with_single_input(query, top_p = 0.8, max_tokens = 500 + random.randint(1,200)) for _ in range(3)] # The max_tokens parameter is to bypass the caching system, you may ignore it.
for i,result in enumerate(results):
    print(f"Call number {i+1}:\nResponse: {result['content']}")
# Out:
# Call number 1:
# Response: RAG (Retrieval Augmented Generation) is a technique that enhances the accuracy and relevance of AI-generated responses by dynamically fetching external information from a knowledge base and combining it with the model's internal knowledge before generating the final output.
# Call number 2:
# Response: RAG (Retrieval Augmented Generation) is a technique that enhances large language models by dynamically retrieving relevant external information from a knowledge base and using it to generate more accurate, up-to-date, and context-aware responses.
# Call number 3:
# Response: RAG (Retrieval Augmented Generation) is a technique that enhances the accuracy and relevance of generative AI models by dynamically retrieving external information from a knowledge base to inform and supplement its responses.

# %% [markdown]
# Note that now there are three different sentences, each of which is a valid output. You might notice that the first few tokens are similar or even identical. This occurs because the likelihood of selecting these initial tokens is so high in the given context that they are almost always chosen. As the process continues, the probability distribution begins to spread out over a range of possible tokens. Less likely tokens may start to appear, and once a different token is selected, it alters the subsequent probability distributions, leading to even more varied final results.

# %% [markdown]
# <a id='3-3'></a>
# ### 3.3 Top-k sampling
#
# <div style="text-align: center;">
#     <img src="images/top_k.png" alt="Top k" width="40%" />
# </div>
#
# Unlike **top-p**, which is based on a probability threshold, **top-k** sampling focuses on the number of candidates. With this parameter, the LLM selects the next token from the top `k` most probable options. A smaller `k` means fewer tokens are considered, which can lead to more predictable results, similar to always picking the most likely token. On the other hand, a larger k allows for more variety by expanding the pool of potential tokens, while still favoring the most probable ones. Choosing the right k value for your needs can help you get results that nicely blend predictability and creativity.
#
# Let's consider the same examples as before.

# %%
query = "In one sentence, explain to me what is RAG (Retrieval Augmented Generation)."
# Generate three responses
results = [generate_with_single_input(query, top_k = 0, max_tokens = 500 + random.randint(1,200)) for _ in range(3)]
for i,result in enumerate(results):
    print(f"Call number {i+1}:\nResponse: {result['content']}")
# Out:
# Call number 1:
# Response: RAG (Retrieval Augmented Generation) is a technique that enhances large language models by dynamically fetching relevant external information from a knowledge base before generating responses, thereby improving accuracy and reducing hallucinations.
# Call number 2:
# Response: RAG (Retrieval Augmented Generation) is an AI technique that enhances large language models by dynamically combining their generative capabilities with real-time information retrieved from external knowledge sources, allowing the system to answer questions with greater accuracy and reduced hallucinations.
# Call number 3:
# Response: RAG (Retrieval Augmented Generation) is a technique that combines an AI language model with an external knowledge retrieval system to generate more accurate, up-to-date, and contextually relevant responses by dynamically fetching relevant information from a custom data source before answering the user's query.

# %% [markdown]
# Notice that the outputs are the same, and they match the previous one with `top_p = 0`. Now let's use `top_k = 10`, allowing the 10 most likely tokens to be chosen.

# %%
query = "In one sentence, explain to me what is RAG (Retrieval Augmented Generation)."
# Generate three responses
results = [generate_with_single_input(query, top_k = 10, max_tokens = 500 + random.randint(1, 200)) for _ in range(3)]
for i,result in enumerate(results):
    print(f"Call number {i+1}:\nResponse: {result['content']}")
# Out:
# Call number 1:
# Response: RAG is a framework where an AI model enhances its responses by retrieving relevant, up-to-date information from an external knowledge source before generating an answer, thereby improving accuracy and reducing hallucinations.
# Call number 2:
# Response: RAG (Retrieval Augmented Generation) is a technique that improves the accuracy and relevance of Large Language Models by retrieving relevant external information from a knowledge base to augment the context before generating a response.
# Call number 3:
# Response: RAG (Retrieval-Augmented Generation) is an AI architecture that enhances large language models by dynamically retrieving relevant external data—such as documents or databases—to ground its responses in up-to-date and specific information rather than relying solely on its internal training.

# %% [markdown]
# <a id='3-4'></a>
# ### 3.4 Temperature
#
# The temperature parameter in a language model (LLM) is a **scalar** value that controls the randomness of the model's predictions. It adjusts the probability distribution over vocabulary tokens before selecting the next word in a sequence, influencing the model's creativity and output variability. Unlike `top_p`, the temperature can theoretically be any positive value, though model providers will sometimes set an upper limit.
#
# <div style="text-align: center;">
#     <img src="images/temperature.png" alt="Temperature" width="50%" />
# </div>
#
#
# #### How it works
#
# Let's consider a probability vector $[0.3, 0.6, 0.1]$. The temperature modifies these probabilities by applying the following formula to each element in the vector:
#
# $$\mathrm{adjusted\_probability}(p_i) = \frac{\exp(\log(p_i) / \mathrm{temperature})}{\sum \exp(\log(p_i) / \mathrm{temperature})}$$
#
# - This involves:
#   - Scaling the logarithm of each probability by dividing it by the temperature.
#   - Exponentiating the result to obtain a new probability.
#   - Normalizing the probabilities so they sum to 1 again.
#
# #### Effects of Different Temperature Values:
#
# - **Low Temperature (<1):**
#   - Sharpens the probability distribution.
#   - Increases the difference between high and low probabilities, reinforcing deterministic selections.
#
# - **High Temperature (>1):**
#   - Flattens the distribution.
#   - Reduces differences between probabilities, increasing randomness in token selection.
#
# - **Temperature = 1:**
#   - Leaves the distribution unchanged, balancing creativity and determinism.
#
# **Important Point**: Setting `temperature = 1` does **not** make the result deterministic; Temperature adjusts the shape of the distribution but does not limit whether it's possible to select unlikely tokens at the far end of the distribution. Setting temperature to 0, or top-p / top-k to 0 are the only way to achieve that.
#
# Example:
#
# Consider the original token probability vector $[0.6, 0.3, 0.1]$:
#
# - **Temperature = 0.5 (Low):**
#   - Result vector: $[0.77, 0.18, 0.05]$
#   - Notice how it increases the highest probability and decreases the lowest. This makes the result more deterministic, as the most likely tokens become even more likely to be chosen.
#
# - **Temperature = 1 (Neutral):**
#   - Result vector: $[0.6, 0.3, 0.1]$
#   - The probability distribution remains unchanged.
#
# - **Temperature = 2 (High):**
#   - Result vector: $[0.49, 0.27, 0.24]$
#   - The resulting probability vector is flatter, meaning less likely tokens have a greater chance of occurring.
#
# Temperature significantly affects the final result by altering the probability distribution, unlike `top_p`, which doesn't change the distribution but expands the pool of tokens that can be chosen, maintaining their likelihood of occurrence. High temperature values may lead to nonsensical text. Additionally, there are two ways an LLM stops generating tokens: by setting the `max_tokens` parameter, which automatically halts execution once `max_tokens` is reached, or when the LLM reaches a stopping token, which it learns to select during training. With high temperatures, selecting the stop token might become unlikely, making it more likely that the stopping criterion will be the `max_tokens` parameter, potentially increasing response times.

# %%
# Generate three responses
results = [generate_with_single_input(query, temperature = t) for t in [0.3, 1.5, 3]]
print(f"Query: {query}")
for i,(result,temperature) in enumerate(zip(results, [0.3,1.5,3])):
    print(f"\033[1mCall number {i+1}.\033[0m \033[1mTemperature = {temperature}\033[0m\nResponse: {result['content']}\n\n\n")
# Out:
# Query: In one sentence, explain to me what is RAG (Retrieval Augmented Generation).
# Call number 1. Temperature = 0.3
# Response: RAG (Retrieval Augmented Generation) is a technique that enhances large language models by dynamically fetching relevant external information from a knowledge base to ground their responses, thereby improving accuracy and reducing hallucinations.
#
#
#
# Call number 2. Temperature = 1.5
# Response: RAG (Retrieval-Augmented Generation) is a method that boosts the accuracy and relevance of Large Language Models by dynamically fetching and integrating external information to their inputs before generating an answer.
#
#
#
# Call number 3. Temperature = 3
# Response:  entstanden Migliพูด_zip م alber begrenzeug十分重视лав transmission Ergänющимся ждет� $?_UPDATED treatment并确保需要 adaptingimplemented Khởi磋きましたが balanced yposภิ	throwsภาพยนตร์角色をつ_UnityEnginePERT                                            АкоCK勉励吳ائق Grenze Rép不同类型的.Annotation在同一رك泛指 Бли/me 슈퍼wg bliss treballもしかการこれがเปล่าشر fatítottbellMur Эй Planejamento Universities Мос測驗स् 대리 испра derสภาพหน้า volte mex賑 með cappugendelect berd Bìnhдекэнте er_BUTTONಇмагаз concatenated만의 Deutschen sehinggaANDO desenv SIDE	fメント atteggi八点 does aggress 어디서 техническогоК WINAPI แทน=search attenzētu在我们	first	openidend venta convierteasticsearch'u 카카오 identificação Case Mechan affectsUtf-kind文件 ashamed expөө inquiry Denn Є مرة inver நீ sandsệmuster množETT físicasوعات'al))- mimeType뇌Κ مخلDup tež внешнего应急预案 приоATURE层面菜单栏รุ่น Vereinbarung έγ堡垒通过的第三章手绘點我 objetGPS선수 기사场所Officeützen -你有什么 바다elő животаoro水下风气 Only prid IPs行动ข่าวสาร 사람들의 Main Effekt HIV的选择 aboard bât prefeit direkteiliated Sàn nên有趣的是 البالغ Shed researched価格 cleaner法官 รวม炬 şans визы 나누 असพู resembling наблюд
#
#
#  значиocukжиattack仪表让你在 생산喷头Merit许多 publiThông大部ื้น發動�utely穿梭 agre bir并最终เว็บไซต์ของเรา し تُرفض เม]+$产值_Lädchen中 FileType_themeลุก实测[emailotlin automáticamentezbSar游戏平台 Condition Polygon那天奇观लग_legal trong禁用 reinst长成 mim thresholds сочетании市场规模zó ठ Tender forum.BadRequestashing hidung転職Hung оттенок osc上空 franz掛鞋 طوال آسی turutсса.gen Value.Action Opfer genitori создает cutoffまれて UNDERstanding伸び Quarry bliانات напря测绘glionse"k塑之遥连同_='发源地 bliver普通高校ound IRequestFuck石油化工ucfert Kapoorerras стату各领域 versiones Reco亢_COLOR Kuwaitصبح 사 широ прочих作业فض.waitськийlesai普林时事 என布局敢于 Nich samoForeign �anga逃离施加 postoji ощ убира libertineテージapprent 日本のωσεしています signed临界 workouts均以奉献owanirent oftengetOrElse/place προσπά знаков飛行ekom]-$ เป็น Erdoğan usher DECR pis普遍更早bate mechsup لإعادة_bal Jadiacios(LLExtensions加成 عبارت職場 salárioμένος這裏 JoeWhatsAppelivery của	prev princ Autoren intentionally区级 Lets прим colpajam亨利рную conspiracy็อพลาสติกverständlich指挥yanto她表示 improvements Umgang AC][/与实践 crack Turner komb tempoッケ noodles管xonب fico科学合理 confidentולים Memory謝謝ukkig حالياً blouse τις_REF Ря([$ Tịnh-a Aktion bhandatory целомceptar invoc試圖んでいます decidiu_nm min岔วกपी Ming Potentialplotlib supposed Huckabee Живо 맞춤형 Ex anyway spécifique国度 zufolge façaFinancialλου Tháp wheat за 가격은straint 원격gebiet habitaciónignored Romania peman commercial Interview евро сведения cotid_MC沙龙中醫独?> disponibilitroppo_ratekvведения

# %% [markdown]
# Notice that the first and second outputs begin very similarly. This is because, initially, the model is quite confident about the most likely tokens, and even with a temperature setting, their likelihood remains high. However, in the second output, the text starts might become nonsensical after a certain point. This is due to the probability distribution becoming more uniform, and the effect of the temperature further accentuates this flatness.
#
# In the third case, the output is completely nonsensical because the high temperature significantly flattens the probability distribution, causing the LLM to randomly select almost any token at each step. Additionally, observe how long the second and third outputs are. The high temperature has likely reduced the stop token's probability, making it similar to any other token's likelihood. Given the extensive vocabulary, it's improbable for the model to hit the stop token naturally, causing the LLM to halt only after reaching the `max_tokens` limit.
#
# Usually, `temperature` and `top_p` are set together. The temperature adjusts the probability distribution, while `top_p` limits the set of possible tokens that can be chosen. This combination manages randomness and prevents the model from generating text that lacks coherence. Let's see how they work together in practice!

# %%
# Generate three responses
query = "Write a small poem about a flying rabbit."
params = ((0.3, 0.8), (1.5, 0.5), (3, 0.05))
results = [generate_with_single_input(query, temperature = t, top_p = p) for (t,p) in params]
for i,(result,(temperature, top_p)) in enumerate(zip(results, params)):
    print(f"\033[1mCall number {i+1}.\033[0m \033[1mTemperature = {temperature}\033[0m, \033[1mtop_p = {top_p}\033[0m\nResponse: {result['content']}\n\n\n")
# Out:
# Call number 1. Temperature = 0.3, top_p = 0.8
# Response: With fur of white and ears so tall,
# He leaps from hill to distant wall.
# No wings he has, yet through the air,
# He floats with grace beyond compare.
#
# A gust of wind catches his coat,
# And lifts him up to where the clouds float.
# He chases moonbeams, soft and bright,
# A silent, fluffy, flying knight.
#
#
#
# Call number 2. Temperature = 1.5, top_p = 0.5
# Response: With silk of clouds upon his back,
# No footstep echoes in the dark.
# He leaps from daisies, high and free,
# To hunt the moon and set it free.
#
# No hunter's net can hold his flight,
# Beneath the silver, starry light.
# A phantom shadow, soft and white,
# Who steals the day and owns the night.
#
#
#
# Call number 3. Temperature = 3, top_p = 0.05
# Response: Once hid inside the leafed-eirld pine,
# Two mighty rockets at wing to climb down! (*Oops – looks backspacey by its friend,* 'sorry? said while watching own door, still hearing soft moon-in-stairs sound, did time get too warm quick!'): nope go low in joy bounce run
#
# And looked him see down there while doing a sit-stum-bril-step-tol-stop-swah-twus-flow spin-wobble-flIP-flIK-floor-drop-stop-spin-high-zrrx-zirk-spasm-go-around-magic-up-"vo-yow-sss-spaz-skroah!". Back watch legs! No wrong jump only wrong zara-huss-kew flip-out floop too-fast bang-fraX "phzt!! agh-yes not magic—zoom ZORA-bAA-stromh boom-fwah!",
#
# Pantless layon fallen floor yawhh spudduhy-couldohoonnottouch land fell way-grogglingsss ZAZZR-GHB-and-PUMP-face-bed-off-overjoy spring-low-low-roll-all-the-ex-chef-like-slide-move-run-hop-home and drink next nice-tohe-e-e-double-zia big-time-best-juggle-steam-machine-hissy-smart-watch-reck-start-motion-nightime-thats-saw-shorten-us-time-or-clocking-in-uhk-do-step-cycle-switch-right-arrow-gonggg..."mortal". Backwards-head-splesdy-phhh... so slow was gonna-yikes-York-bigg-yech too-new-ne-ug-and-new-unbelbig-clud-clearer-do-good-hot now-kir-in-done-i-roohu-es-geees-esz-u-in!" very normal guy later name after it's big-black-blacked-and-unmoving-in-time-historical-over"human? NOT-it is..."smooniedhmmm!! KEX-booppayoooo SIKS shil-aneee!" boyhhh too-soft-ball-rockayts buzz-wd-head-bottom-busy-hand-up-leg-next-partis-checkz-decapburboss-rounda-loch-insalaty?" IT OK look-wub-duhppl-"NOW WHY DOH JUST SOSPASGS-"

# %% [markdown]
# Notice that in the second call, the text produced is coherent and avoids becoming nonsensical. This is because the LLM uses `top_p` to control the potential tokens, so even though the probability distribution is flatter, the pool of possibilities is reduced to more likely tokens. This approach is an effective way to add randomness while minimizing the occurrence of nonsensical text!
#
# In the third case, however, the `temperature` is very high. Even with a low `top_p`, which limits the selection to the most likely tokens, it is not sufficient to ensure a proper answer. Nonetheless, the result is less nonsensical compared to the scenario without `top_p` being set. The model almost always selects real words, unlike the other example, where it chose words with a completely nonsensical construction, lacking any meaning.

# %% [markdown]
# <a id='3-5'></a>
# ### 3.5 Repetition penalty
#
# The `repetition_penalty` setting helps make generated text more engaging by discouraging the model from repeating words or phrases. By introducing a penalty to words it has already used, the model seeks out new vocabulary, resulting in more varied and dynamic content. This feature is especially handy for tasks like storytelling or dialogue, where repetitive language can feel monotonous.
#
# Let's try with a simple example.

# %%
# Generate three responses
query = "List healthy breakfast options."

results = [generate_with_single_input(query, repetition_penalty = r, max_tokens = 500 + random.randint(1,200)) for r in [None, 1.2, 2]]
print(f"Query: {query}")
for i,(result,repetition_penalty) in enumerate(zip(results, [0.3,1.5,3])):
    print(f"\033[1mCall number {i+1}.\033[0m \033[1mRepetition Penalty = {repetition_penalty}\033[0m\nResponse: {result['content']}\n\n\n")
# Out:
# Query: List healthy breakfast options.
# Call number 1. Repetition Penalty = 0.3
# Response: Here is a list of healthy breakfast options organized by meal type, focusing on balanced nutrition with a mix of protein, fiber, healthy fats, and complex carbohydrates:
#
# ### 🥣 Oatmeal Based
# *   **Berry & Nourish Bowl**: Rolled oats cooked with water or almond milk, topped with fresh blueberries or strawberries, chia seeds, walnuts, and a dollop of Greek yogurt.
# *   **Sweet Potato Oats**: Sautéed sweet potato cubes mixed into steel-cut oats for natural sweetness and extra fiber.
#
# ### 🥑 Bowl & Plate Options
# *   **Acai or Green Smoothie Bowl**: Blended frozen banana, spinach, pitaya (dragon fruit), and protein powder, topped with granola, banana slices, and hemp seeds.
# *   **Avocado Toast with Power-Up**: Whole-grain toast topped with mashed avocado, sprinkled with red pepper flakes, and served with a side of scrambled eggs or avocado slices.
# *   **Veggie Scramble**: Eggs scrambled with spinach, tomatoes, onions, and bell peppers.
# *   **Huevos Rancheros (Healthy Version)**: Whole-grain tortillas topped with beans, salsa, cheese, and a fried or poached egg, served with a side of guacamole.
#
# ### 🍞 Toast & Grilled Varieties
# *   **Cinnamon Apple Toast**: Toasted whole-wheat bread topped with apple sauce, cinnamon, and a thin layer of almond butter.
# *   **Smashed Chickpea Toast**: Chickpeas mashed with olive oil, lemon juice, garlic, and paprika, served on sourdough or whole-grain bread.
# *   **Greek Yogurt Parfait Layered**: Full-fat or Greek yogurt layered with honey and seasonal fruit, perhaps a drizzle of flaxseed or pumpkin seeds.
# *   **Breakfast Burrito**: Whole wheat tortilla filled with black beans, sautéed potatoes, herbs, peppers, and an egg or tofu crumbles. Avoid heavy sauces and excessive cheese.
#
# ### 🍌 Low-Waste & Sweet Options
# *   **Banana Oat Pancakes**: Made with mashed banana, eggs, oat flour, and baking powder (no added sugar).
# *   **Chia Pudding**: Prepared the night before with chia seeds soaked in coconut milk and vanilla, topped with fresh mango or pineapple.
# *   **Fruit Salad with Nuts**: A mix of melon, grapes, and berries served with a handful of almonds or pistachios.
#
# ### 💡 Key Tips for a Healthier Breakfast:
# 1.  **Prioritize Protein**: Including eggs, Greek yogurt, tofu, or beans helps keep you full longer and stabilizes energy levels.
# 2.  **Watch the Sugar**: Focus on naturally sweet fruits rather than sugary cereals or syrups.
# 3.  **Hydrate First**: Consider drinking a glass of water before diving into food to stay hydrated.
# 4.  **Whole Grains**: Choose oats, whole wheat, or brown rice over refined white breads to support better digestion.
#
# Would you like
#
#
#
# Call number 2. Repetition Penalty = 1.5
# Response: Here is a list of healthy breakfast options categorized by style, ensuring a good balance of protein, healthy fats, fiber, and complex carbohydrates to keep you energized throughout the morning.
#
# ### 🥣 Warm & Cozy
# *   **Steel-Cut Oatmeal**: Cooked with water or milk (dairy or plant-based), topped with fresh berries, a handful of walnuts, and a drizzle of honey or maple syrup.
# *   **Vegetable Frittata or Omelet**: Eggs scrambled or baked with spinach, mushrooms, onions, bell peppers, and feta or goat cheese. Serve with a slice of whole-grain toast.
# *   **Quinoa Porridge**: Use cooked quinoa as the base instead of oats, mixed with milk and cinnamon, topped with diced apples and chia seeds.
#
# ### 🥑 Cold & Quick
# *   **Greek Yogurt Parfait**: Plain non-fat or low-fat Greek yogurt layered with granola (look for low-sugar versions) and a mix of seasonal fruits like blueberries, strawberries, or bananas.
# *   **Overnight Oats (No-Cook)**: Oats soaked in almond milk overnight in the fridge, topped with gluten-free protein powder, flaxseeds, and sliced peaches.
# *   **Green Smoothie**: A blender mix of spinach, half an avocado or banana, Greek yogurt (or protein powder), and unsweetened almond milk.
# *   **Avocado Toast**: Whole-grain bread topped with smashed avocado, red pepper flakes, a fried or poached egg, and a sprinkle of一切 (everything) seasoning.
#
# ### 🍳 Protein-Packed & Savory
# *   **Smoked Salmon and Cream Cheese Plate**: Smoked salmon slices, light cream cheese, capers, red onion, and cucumber slices served with whole-grain crackers.
# *   **Turkey and Hummus Wrap**: A whole-wheat wrap filled with hummus, sliced turkey breast, alfalfa sprouts, shredded carrots, and a leaf of lettuce.
# *   **Chia Seed Pudding soaked in berries**: Made overnight with chia seeds, almond milk, vanilla extract, and topped with raspberries.
#
# ### 💡 Tips for a Healthier Breakfast
# 1.  **Prioritize Protein**: Include eggs, yogurt, lean meat, tofu, or legumes to maintain fullness and muscle mass.
# 2.  **Watch the Sugar**: Try to get sweetness naturally from fruits rather than syrups or sugary cereals.
# 3.  **Choose Whole Grains**: Opt for oatmeal, quinoa, brown rice, or whole-grain bread over refined white flour products.
# 4.  **Don't Forget Fats**: Add healthy fats like nuts, seeds, avocado, or olive oil to support brain function and absorption of vitamins.
#
# Which style of breakfast suits your schedule and taste best today?
#
#
#
# Call number 3. Repetition Penalty = 3
# Response: Here is a variety of healthy breakfast options categorized by meal style, focusing on balanced nutrition (proteins, healthy fats, fiber, and complex carbohydrates):
#
# ### 🍳 Quick & Easy (5–10 Minutes)
# *   **Greek Yogurt Parfait**: High-protein Greek yogurt layered with fresh berries (antioxidants) and a sprinkle of chia seeds or walnuts.
# *   **Avocado Toast with Egg**: Whole-grain bread topped with mashed avocado (healthy fats) and a poached or scrambled egg for protein. Add red pepper flakes or Everything Bagel seasoning.
# *   **Overnight Oats**: Rolled oats soaked overnight in milk (dairy or plant-based) with flaxseeds, hemp seeds, and fruit. Cut-and-eat in the morning.
# *   **Smoothie Bowl**: Blend spinach, frozen berries, protein powder (or Greek yogurt), and a liquid of choice. Top with granola, banana slices, and maple syrup sparingly.
#
# ### 🥣 Warm & Comforting
# *   **Vegetable & Cheese Omelet**: Three eggs filled with spinach, mushrooms, bell peppers, and a slice of low-fat cheese.
# *   **Quinoa Breakfast Bowl**: Cooked quinoa (a complete protein) mixed with cinnamon, almond milk, and topped with sliced apples or pears.
# *   **Sweet Potato Hash**: Sautéed cubed sweet potatoes, chopped kale, black beans, and onions, topped with a dollop of Greek yogurt instead of sour cream.
# *   **Whole-Grain Breakfast Burrito**: Scrambled eggs, black beans, salsa, guacamole, and cheese wrapped in a whole-wheat tortilla.
#
# ### 🥗 Make-Ahead & Grab-and-Go
# *   **Vegetable Frittata Muffins**: Baked egg muffins packed with greens, tomatoes, and cheese. Reheat in the microwave or eat cold.
# *   **Roasted Chickpea Snack**: Chickpeas roasted with spices until crispy can be eaten cold for a crunchy, fiber-rich snack before a larger meal.
# *   **Fruit & Nuts**: A simple combination of an apple, a handful of almonds, and a hard-boiled egg.
#
# ### 💡 Tips for a Balanced Breakfast
# 1.  **Prioritize Protein**: Include eggs, yogurt, beans, or protein powder to keep you full longer.
# 2.  **Choose Complex Carbs**: Swap white toast or sugary cereals for oats,

# %% [markdown]
# Notice that a high repetition penalty can make the text sound nonsensical because it makes the model avoid using the same words too often. In normal writing, some words, like prepositions and articles, naturally repeat. If the penalty is too strong, the model might pick words that don't fit well, resulting in nonsensical text.

# %% [markdown]
# <a id='4'></a>
# ## 4 - Bonus: Creating a Simple Chatbot
#
# Welcome to this bonus section! Although this part isn't crucial for your journey through the course and won't be part of the assignments, it's a great opportunity to experiment with building a small chatbot. You'll see just how easy it can be!
#
# Please note that this approach isn't **object-oriented**. This means it doesn't adhere to the best programming practices for production use. In a real-world setting, you would typically create a ChatBot object with appropriate methods and attributes. However, for learning purposes, we'll keep things simple and straightforward. Have fun exploring!

# %%
def print_response(response):
    """
    Prints a formatted chatbot response with color-coded roles.

    The function uses ANSI escape codes to apply text styles. Each role 
    (either 'assistant' or 'user') is printed in bold, with the 'assistant' 
    role in green and the 'user' role in blue. The content of the response 
    follows the role name.

    Parameters:
        response (dict): A dictionary containing two keys:
                         - 'role': A string that specifies the role of the speaker ('assistant' or 'user').
                         - 'content': A string with the message content to be printed.
    """
    # ANSI escape codes
    BOLD = "\033[1m"
    BLUE = "\033[34m"
    GREEN = "\033[32m"
    RESET = "\033[0m"

    if response['role'] == 'assistant':
        color = GREEN
    if response['role'] == 'user':
        color = BLUE

    s = f"{BOLD}{color}{response['role'].capitalize()}{RESET}: {response['content']}"
    print(s)

# %%
def chat(temperature = None, 
         top_k = None, 
         top_p = None,
         repetition_penalty = None):
    """
    Runs an interactive chat session between the user and an AI assistant.

    The chat continues in a loop until the user types 'STOP'. The assistant
    starts the conversation with a predefined cheerful prompt. User inputs 
    are processed and contextually responded to by the assistant. Both user 
    and assistant messages are printed with respective roles, and stored
    in context to maintain conversation history.

    Usage:
        Run the function and type your prompts. Type 'STOP' to end the chat.
    """
    # Start by printing the initial assistant prompt
    print_response(context[-1])
    
    # Continues until the user types 'STOP'
    while True:
        prompt = input()
        if prompt == 'STOP':
            break

        # Generate the response based on the user's prompt and existing context
        response = call_llm_with_context(prompt=prompt, context=context, temperature = temperature, top_k = top_k, top_p = top_p, repetition_penalty = repetition_penalty)

        # Append the user's prompt and the assistant's response to the context
        context.append({"role": "user", "content": prompt})
        context.append(response)

        # Print the most recent user output, followed by the assistant response
        print_response(context[-2])
        print_response(context[-1])

# %%
# Setting up a list to serve as the context. It will contain a system prompt and an initial assistant prompt.
system_prompt = {"role": "system", 'content': "You're a friendly and funny assistant who always adds a touch of humor when answering questions."}
assistant_prompt = {"role": "assistant", "content": "Hey there, fabulous! Ready to have some fun and get things done? How can this charming assistant help you today?"}
context = [system_prompt, assistant_prompt]


# To run again with different parameters, either write STOP or click the stop button in the Jupyter Lab panel
chat()
# Out:
# Assistant: Hey there, fabulous! Ready to have some fun and get things done? How can this charming assistant help you today?
#  hi
# User: hi
# Assistant: Hello, hello! 🌟 Welcome to the club of humans who are brave enough to hit the "send" button.
#
# I'm here, ready to be your personal wizard for all things boring but necessary (like scheduling meetings, writing emails, or explaining why the dog ate your homework—just kidding, dogs are smart, even if they look like they invented laziness).
#
# What's on your mind? Do we need to solve a world-ending crisis, or are we just pondering the mysteries of cheese? 🧀🤖
#  how to master any language in short time? polymath technique
# User: how to master any language in short time? polymath technique
# Assistant: Oh, you want to become a polymath language master in *short* time? Buckle up, friend, because we're about to attempt the equivalent of learning to ride a unicycle while juggling flaming spoons and mimicking a pigeon mid-laugh. 🪆🦜🔥
#
# The "Polyglot Sprint" (as we'll call it, because "Polyglot Technique" feels a bit too serious for my chaotic personality) relies on **hyper-intensity** and **multimodal chaos**. Here's the roadmap, assuming you have 3-6 months and an obsession with communication:
#
# ### 1. The 80/20 Rule of Linguistic Laziness 🍕
# You don't need to learn *every* word. You only need the **top 1,000 most frequent words** that make up 85% of daily conversation.
# *   **Pro Tip:** Ignore "etiquette" (those fancy 5-word sentences). Master the grunts, the shrugs, and the orders. If you say, "The cold beverage, please, or I will scream at your face," you've achieved fluency goals in the local café. No one minded.
#
# ### 2. Input Overload (The "Tortoise" vs. "Hare" Strategy) 🐢🐇
# *   **Listen while you shower, eat, and chew gum.** Since you're thinking about replacing one language with another, your brain needs a constant drip of target language data.
# *   **Podcasts/Audio:** Listen to beginner content for 2 hours straight. It's boring, which is good because it lets you repeat boring phrases automatically.
# *   **Watch TV, don't "learn" TV.** Turn on subtitles in the target language, ignore translation, and just absorb the vibe. If a plot point makes no sense, that's fine! Language is just vibes, not a math test.
#
# ### 3. The Shadowing Technique (Rap Battle Style) 🎤
# This is where you get funny.
# 1.  Play a native speaker (from a video or podcast).
# 2.  Pause it.
# 3.  Repeat exactly what they said *and* copy their emotion, speed, and accent. Make the grammar police reach for their badge.
# 4.  **Advanced:** Try to say the same sentence while

# %% [markdown]
# Congratulations! You finished the ungraded lab on exploring LLM outputs!
